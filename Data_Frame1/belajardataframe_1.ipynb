# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a4246bab7dfd> in <module>
# ----> 1 df = pd.read_csv("dataset/dataset.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File dataset/dataset.csv does not exist: 'dataset/dataset.csv'

# %%
df = pd.read_csv("dataset/dataset_123.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-94e3dd5fd0a7> in <module>
# ----> 1 df = pd.read_csv("dataset/dataset_123.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File dataset/dataset_123.csv does not exist: 'dataset/dataset_123.csv'

# %%
df = pd.read_csv("dataset/dataset_baru.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b5a43533bc47> in <module>
# ----> 1 df = pd.read_csv("dataset/dataset_baru.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File dataset/dataset_baru.csv does not exist: 'dataset/dataset_baru.csv'

# %%
df = pd.read_csv("../dataset/dataset_baru.csv")

# %%
df.head()
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df.dtypes
# Out:
# order_id         object
# order_date       object
# customer_id      object
# segment          object
# category         object
# sub_category     object
# sales           float64
# quantity          int64
# profit          float64
# dtype: object

# %%
df = pd.read_csv("../dataset/dataset_baru.csv", parse_dates["order_date"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a5bb65a9fe43> in <module>
# ----> 1 df = pd.read_csv("../dataset/dataset_baru.csv", parse_dates["order_date"])
#
# NameError: name 'parse_dates' is not defined

# %%
df = pd.read_csv("../dataset/dataset_baru.csv", parse_dates["order_date"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ea4dbbd07b52> in <module>
# ----> 1 df = pd.read_csv("../dataset/dataset_baru.csv", parse_dates["order_date"])
#       2 df.head()
#
# NameError: name 'parse_dates' is not defined

# %%
df = pd.read_csv("../dataset/dataset_baru.csv", parse_dates=["order_date"])
df.head()
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df.dtypes
# Out:
# order_id                object
# order_date      datetime64[ns]
# customer_id             object
# segment                 object
# category                object
# sub_category            object
# sales                  float64
# quantity                 int64
# profit                 float64
# dtype: object

# %%
order_ids = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688", "US-2015-108966" , "US-2015-108966"]
couriers = ["courier A", "courier A" , None , "courier B", "courier B"]

df.couriers = pd.DataFrame({
    "oder_id" : order_ids,
    "courier" : couriers,
})
df_courier.head()
# Out:
# C:\Users\Fachriezal\anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b69b157a132b> in <module>
#       6     "courier" : couriers,
#       7 })
# ----> 8 df_courier.head()
#
# NameError: name 'df_courier' is not defined

# %%
order_ids = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688", "US-2015-108966" , "US-2015-108966"]
couriers = ["Courier A", "Courier A" , None , "Courier B", "Courier B"]

df.couriers = pd.DataFrame({
    "oder_id" : order_ids,
    "courier" : couriers,
})
df_courier.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3dd463954473> in <module>
#       6     "courier" : couriers,
#       7 })
# ----> 8 df_courier.head()
#
# NameError: name 'df_courier' is not defined

# %%
order_ids = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688", "US-2015-108966" , "US-2015-108966"]
couriers = ["Courier A", "Courier A" , None , "Courier B", "Courier B"]

df.courier = pd.DataFrame({
    "oder_id" : order_ids,
    "courier" : couriers,
})
df_courier.head()
# Out:
# C:\Users\Fachriezal\anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f8d5e234527f> in <module>
#       6     "courier" : couriers,
#       7 })
# ----> 8 df_courier.head()
#
# NameError: name 'df_courier' is not defined

# %%
order_ids = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688", "US-2015-108966" , "US-2015-108966"]
couriers = ["Courier A", "Courier A" , None , "Courier B", "Courier B"]

df_courier = pd.DataFrame({
    "oder_id" : order_ids,
    "courier" : couriers,
})
df_courier.head()
# Out:
#           oder_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_courier.isna()
# Out:
#    oder_id  courier
# 0    False    False
# 1    False    False
# 2    False     True
# 3    False    False
# 4    False    False

# %%
df_courier.isna().any("columns")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df_couriers[df_courier.isna().any("columns")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2f8cb6226471> in <module>
# ----> 1 df_couriers[df_courier.isna().any("columns")]
#
# NameError: name 'df_couriers' is not defined

# %%
df_courier[df_courier.isna().any("columns")]
# Out:
#           oder_id courier
# 2  CA-2016-138688    None

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv")

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv", index=false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4fbaf3aeb274> in <module>
# ----> 1 df_courier.to_csv("../dataset/dataset_barukkk.csv", index=false)
#
# NameError: name 'false' is not defined

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv", index = false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5a73822f23ca> in <module>
# ----> 1 df_courier.to_csv("../dataset/dataset_barukkk.csv", index = false)
#
# NameError: name 'false' is not defined

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv", index : false)
# Out:
#   File "<ipython-input-29-5469798fe395>", line 1
#     df_courier.to_csv("../dataset/dataset_barukkk.csv", index : false)
#                                                               ^
# SyntaxError: invalid syntax

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv", index = "false")

# %%
df_courier.to_csv("../dataset/dataset_barukkk.csv", index = False)

# %%
df_head = df.head()

# %%
df_tail = df.tail()

# %%
df_head
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df_tail
# Out:
#             order_id order_date customer_id   segment         category  \
# 9983  CA-2014-110422 2014-01-21    TB-21400  Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060  Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060  Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060  Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220  Consumer  Office Supplies
#
#      sub_category    sales  quantity   profit
# 9983  Furnishings   25.248         3   4.1028
# 9984  Furnishings   91.960         2  15.6332
# 9985       Phones  258.576         2  19.3932
# 9986        Paper   29.600         4  13.3200
# 9987   Appliances  243.160         2  72.9480

# %%
df_congcat = pd.congcat([df_tail, df_head])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ab89e6a8453e> in <module>
# ----> 1 df_congcat = pd.congcat([df_tail, df_head])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'congcat'

# %%
df_concat = pd.congcat([df_tail, df_head])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b82ae418523d> in <module>
# ----> 1 df_concat = pd.congcat([df_tail, df_head])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'congcat'

# %%
df_concat = pd.concat([df_tail, df_head])

# %%
df_concat
# Out:
#             order_id order_date customer_id    segment         category  \
# 9983  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 0     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 9983  Furnishings   25.2480         3    4.1028
# 9984  Furnishings   91.9600         2   15.6332
# 9985       Phones  258.5760         2   19.3932
# 9986        Paper   29.6000         4   13.3200
# 9987   Appliances  243.1600         2   72.9480
# 0       Bookcases  261.9600         2   41.9136
# 1          Chairs  731.9400         3  219.5820
# 2          Labels   14.6200         2    6.8714
# 3          Tables  957.5775         5 -383.0310
# 4         Storage   22.3680         2    2.5164

# %%
df_concat = pd.concat([df_tail, df_head], ignore_index = true )
df_concat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e4008fcb5aa5> in <module>
# ----> 1 df_concat = pd.concat([df_tail, df_head], ignore_index = true )
#       2 df_concat
#
# NameError: name 'true' is not defined

# %%
df_concat = pd.concat([df_tail, df_head], ignore_index = True )
df_concat
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0  Furnishings   25.2480         3    4.1028
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 3        Paper   29.6000         4   13.3200
# 4   Appliances  243.1600         2   72.9480
# 5    Bookcases  261.9600         2   41.9136
# 6       Chairs  731.9400         3  219.5820
# 7       Labels   14.6200         2    6.8714
# 8       Tables  957.5775         5 -383.0310
# 9      Storage   22.3680         2    2.5164

# %%
df_concat.short_values("oder_date")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-29dc700343f6> in <module>
# ----> 1 df_concat.short_values("oder_date")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'short_values'

# %%
df_concat.sort_values("oder_date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-e2067662bbb0> in <module>
# ----> 1 df_concat.sort_values("oder_date")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'oder_date'

# %%
df_concat.sort_values("oder_date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-e2067662bbb0> in <module>
# ----> 1 df_concat.sort_values("oder_date")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'oder_date'

# %%
df_concat.short_values("oder_date", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-15e6a0df65e5> in <module>
# ----> 1 df_concat.short_values("oder_date", ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'short_values'

# %%
df_concat.sort_values("oder_date", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-6b0e807f5e19> in <module>
# ----> 1 df_concat.sort_values("oder_date", ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'oder_date'

# %%
df_concat.short_values("quantity", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-0bb10cc3862f> in <module>
# ----> 1 df_concat.short_values("quantity", ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'short_values'

# %%
df_concat.sort_values("quantity", ascending = False)
# Out:
#          order_id order_date customer_id    segment         category  \
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 8       Tables  957.5775         5 -383.0310
# 3        Paper   29.6000         4   13.3200
# 0  Furnishings   25.2480         3    4.1028
# 6       Chairs  731.9400         3  219.5820
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 4   Appliances  243.1600         2   72.9480
# 5    Bookcases  261.9600         2   41.9136
# 7       Labels   14.6200         2    6.8714
# 9      Storage   22.3680         2    2.5164

# %%
df_concat.sort_values("quantity")
# Out:
#          order_id order_date customer_id    segment         category  \
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 4   Appliances  243.1600         2   72.9480
# 5    Bookcases  261.9600         2   41.9136
# 7       Labels   14.6200         2    6.8714
# 9      Storage   22.3680         2    2.5164
# 0  Furnishings   25.2480         3    4.1028
# 6       Chairs  731.9400         3  219.5820
# 3        Paper   29.6000         4   13.3200
# 8       Tables  957.5775         5 -383.0310

# %%
df_concat.sort_values("order_date")
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0  Furnishings   25.2480         3    4.1028
# 8       Tables  957.5775         5 -383.0310
# 9      Storage   22.3680         2    2.5164
# 7       Labels   14.6200         2    6.8714
# 5    Bookcases  261.9600         2   41.9136
# 6       Chairs  731.9400         3  219.5820
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 3        Paper   29.6000         4   13.3200
# 4   Appliances  243.1600         2   72.9480

# %%
df_concat.sort_values("order_date", ascending = False)
# Out:
#          order_id order_date customer_id    segment         category  \
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 4   Appliances  243.1600         2   72.9480
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 3        Paper   29.6000         4   13.3200
# 5    Bookcases  261.9600         2   41.9136
# 6       Chairs  731.9400         3  219.5820
# 7       Labels   14.6200         2    6.8714
# 8       Tables  957.5775         5 -383.0310
# 9      Storage   22.3680         2    2.5164
# 0  Furnishings   25.2480         3    4.1028

# %%
df_concat = df_concat.sort_values("order_date", ascending = False)

# %%
df_concat
# Out:
#          order_id order_date customer_id    segment         category  \
# 4  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 1  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 2  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 3  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 5  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 6  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 7  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 8  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 9  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 0  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 4   Appliances  243.1600         2   72.9480
# 1  Furnishings   91.9600         2   15.6332
# 2       Phones  258.5760         2   19.3932
# 3        Paper   29.6000         4   13.3200
# 5    Bookcases  261.9600         2   41.9136
# 6       Chairs  731.9400         3  219.5820
# 7       Labels   14.6200         2    6.8714
# 8       Tables  957.5775         5 -383.0310
# 9      Storage   22.3680         2    2.5164
# 0  Furnishings   25.2480         3    4.1028

# %%
df_head = df.iloc(2:7)
df_head
# Out:
#   File "<ipython-input-56-b06f00ae9449>", line 1
#     df_head = df.iloc(2:7)
#                        ^
# SyntaxError: invalid syntax

# %%
df_head = df.iloc[2:7]
df_head
# Out:
#          order_id order_date customer_id    segment         category  \
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-115812 2014-06-09    BH-11710   Consumer        Furniture
# 6  CA-2014-115812 2014-06-09    BH-11710   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# 5  Furnishings   48.8600         7   14.1694
# 6          Art    7.2800         4    1.9656

# %%
df_courier
# Out:
#           oder_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_merge = pd.merge(df_head, df_courier, how="left" , on="order_id")
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-ce1a5f5abc52> in <module>
# ----> 1 df_merge = pd.merge(df_head, df_courier, how="left" , on="order_id")
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'order_id'

# %%
df_merge = pd.merge(df_head, df_courier ,how="left" ,on="order_id")
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-d384f2976198> in <module>
# ----> 1 df_merge = pd.merge(df_head, df_courier ,how="left" ,on="order_id")
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'order_id'

# %%
df_merge = pd.merge(df_head, df_courier ,how:"left" ,on:"order_id")
df_merge
# Out:
#   File "<ipython-input-67-49282fd20655>", line 1
#     df_merge = pd.merge(df_head, df_courier ,how:"left" ,on:"order_id")
#                                                 ^
# SyntaxError: invalid syntax

# %%
df_merge = pd.merge(df_head, df_courier ,how="left" ,on= "order_id")
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b35433b864e4> in <module>
# ----> 1 df_merge = pd.merge(df_head, df_courier ,how="left" ,on= "order_id")
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'order_id'

# %%
df_head = df.iloc[2:7]
df_head
# Out:
#          order_id order_date customer_id    segment         category  \
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-115812 2014-06-09    BH-11710   Consumer        Furniture
# 6  CA-2014-115812 2014-06-09    BH-11710   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# 5  Furnishings   48.8600         7   14.1694
# 6          Art    7.2800         4    1.9656

# %%
df_courier
# Out:
#           oder_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_merge = pd.merge(df_courier, df_head ,how='Left', on='Order_Id')
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-1577f3128621> in <module>
# ----> 1 df_merge = pd.merge(df_courier, df_head ,how='Left', on='Order_Id')
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Order_Id'

# %%
df_merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-31dcbc946508> in <module>
# ----> 1 df_merge
#
# NameError: name 'df_merge' is not defined

# %%
df_merge()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-6ff0912571cc> in <module>
# ----> 1 df_merge()
#
# NameError: name 'df_merge' is not defined

# %%
df_merge = pd.merge(df_courier, df_head ,how='Left', on='Order_Id')
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-1577f3128621> in <module>
# ----> 1 df_merge = pd.merge(df_courier, df_head ,how='Left', on='Order_Id')
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Order_Id'

# %%
df_head = df.iloc[3:7]
df_head
# Out:
#          order_id order_date customer_id   segment         category  \
# 3  US-2015-108966 2015-10-11    SO-20335  Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335  Consumer  Office Supplies
# 5  CA-2014-115812 2014-06-09    BH-11710  Consumer        Furniture
# 6  CA-2014-115812 2014-06-09    BH-11710  Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# 5  Furnishings   48.8600         7   14.1694
# 6          Art    7.2800         4    1.9656

# %%
df_courier
# Out:
#           oder_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_merge = pd.merge(df_courier, df_head ,how="Left", on="oder_id")
df_merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-fc65a6eddd82> in <module>
# ----> 1 df_merge = pd.merge(df_courier, df_head ,how="Left", on="oder_id")
#       2 df_merge
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'oder_id'

# %%
order_ids = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688", "US-2015-108966" , "US-2015-108966"]
couriers = ["Courier A", "Courier A" , None , "Courier B", "Courier B"]

df_courier = pd.DataFrame({
    "order_id" : order_ids,
    "courier" : couriers,
})
df_courier.head()
# Out:
#          order_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_head = df.iloc[3:7]
df_head
# Out:
#          order_id order_date customer_id   segment         category  \
# 3  US-2015-108966 2015-10-11    SO-20335  Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335  Consumer  Office Supplies
# 5  CA-2014-115812 2014-06-09    BH-11710  Consumer        Furniture
# 6  CA-2014-115812 2014-06-09    BH-11710  Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# 5  Furnishings   48.8600         7   14.1694
# 6          Art    7.2800         4    1.9656

# %%
df_courier
# Out:
#          order_id    courier
# 0  CA-2016-152156  Courier A
# 1  CA-2016-152156  Courier A
# 2  CA-2016-138688       None
# 3  US-2015-108966  Courier B
# 4  US-2015-108966  Courier B

# %%
df_merge = pd.merge(df_courier, df_head ,how="left", on="order_id")
df_merge
# Out:
#          order_id    courier order_date customer_id   segment  \
# 0  CA-2016-152156  Courier A        NaT         NaN       NaN
# 1  CA-2016-152156  Courier A        NaT         NaN       NaN
# 2  CA-2016-138688       None        NaT         NaN       NaN
# 3  US-2015-108966  Courier B 2015-10-11    SO-20335  Consumer
# 4  US-2015-108966  Courier B 2015-10-11    SO-20335  Consumer
# 5  US-2015-108966  Courier B 2015-10-11    SO-20335  Consumer
# 6  US-2015-108966  Courier B 2015-10-11    SO-20335  Consumer
#
#           category sub_category     sales  quantity    profit
# 0              NaN          NaN       NaN       NaN       NaN
# 1              NaN          NaN       NaN       NaN       NaN
# 2              NaN          NaN       NaN       NaN       NaN
# 3        Furniture       Tables  957.5775       5.0 -383.0310
# 4  Office Supplies      Storage   22.3680       2.0    2.5164
# 5        Furniture       Tables  957.5775       5.0 -383.0310
# 6  Office Supplies      Storage   22.3680       2.0    2.5164

# %%
df_merge.drop(columns=["customer_id", "segment"])
# Out:
#          order_id    courier order_date         category sub_category  \
# 0  CA-2016-152156  Courier A        NaT              NaN          NaN
# 1  CA-2016-152156  Courier A        NaT              NaN          NaN
# 2  CA-2016-138688       None        NaT              NaN          NaN
# 3  US-2015-108966  Courier B 2015-10-11        Furniture       Tables
# 4  US-2015-108966  Courier B 2015-10-11  Office Supplies      Storage
# 5  US-2015-108966  Courier B 2015-10-11        Furniture       Tables
# 6  US-2015-108966  Courier B 2015-10-11  Office Supplies      Storage
#
#       sales  quantity    profit
# 0       NaN       NaN       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       NaN
# 3  957.5775       5.0 -383.0310
# 4   22.3680       2.0    2.5164
# 5  957.5775       5.0 -383.0310
# 6   22.3680       2.0    2.5164

# %%
df_merge[["order_date", "category", "courier"]]
# Out:
#   order_date         category    courier
# 0        NaT              NaN  Courier A
# 1        NaT              NaN  Courier A
# 2        NaT              NaN       None
# 3 2015-10-11        Furniture  Courier B
# 4 2015-10-11  Office Supplies  Courier B
# 5 2015-10-11        Furniture  Courier B
# 6 2015-10-11  Office Supplies  Courier B

# %%
df_groupby = df.groupby(["order_date", "category"]).agg({
    "sales" : "sum",
})
df_groupby
# Out:
#                                sales
# order_date category
# 2014-01-03 Office Supplies    16.448
# 2014-01-04 Office Supplies   288.060
# 2014-01-05 Office Supplies    19.536
# 2014-01-06 Furniture        2573.820
#            Office Supplies   685.340
# ...                              ...
# 2017-12-29 Office Supplies   282.440
#            Technology        302.376
# 2017-12-30 Furniture         323.136
#            Office Supplies   299.724
#            Technology         90.930
#
# [2859 rows x 1 columns]

# %%
df["order_month"]= df.order_date.dt.strftime("%y-%m")
df.head()
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit order_month
# 0    Bookcases  261.9600         2   41.9136       16-11
# 1       Chairs  731.9400         3  219.5820       16-11
# 2       Labels   14.6200         2    6.8714       16-06
# 3       Tables  957.5775         5 -383.0310       15-10
# 4      Storage   22.3680         2    2.5164       15-10

# %%
df_groupby = df.groupby(["order_date", "category"]).agg({
    "sales" : "sum",
})
df_groupby
# Out:
#                                sales
# order_date category
# 2014-01-03 Office Supplies    16.448
# 2014-01-04 Office Supplies   288.060
# 2014-01-05 Office Supplies    19.536
# 2014-01-06 Furniture        2573.820
#            Office Supplies   685.340
# ...                              ...
# 2017-12-29 Office Supplies   282.440
#            Technology        302.376
# 2017-12-30 Furniture         323.136
#            Office Supplies   299.724
#            Technology         90.930
#
# [2859 rows x 1 columns]

# %%
df_groupby = df_groupby.reset_index()
df_groupby
# Out:
#      order_date         category     sales
# 0    2014-01-03  Office Supplies    16.448
# 1    2014-01-04  Office Supplies   288.060
# 2    2014-01-05  Office Supplies    19.536
# 3    2014-01-06        Furniture  2573.820
# 4    2014-01-06  Office Supplies   685.340
# ...         ...              ...       ...
# 2854 2017-12-29  Office Supplies   282.440
# 2855 2017-12-29       Technology   302.376
# 2856 2017-12-30        Furniture   323.136
# 2857 2017-12-30  Office Supplies   299.724
# 2858 2017-12-30       Technology    90.930
#
# [2859 rows x 3 columns]

# %%
df_groupby = df_groupby.rename(columns=
                              {
                                  "order_date" : "date",
                              })
df_groupby
# Out:
#            date         category     sales
# 0    2014-01-03  Office Supplies    16.448
# 1    2014-01-04  Office Supplies   288.060
# 2    2014-01-05  Office Supplies    19.536
# 3    2014-01-06        Furniture  2573.820
# 4    2014-01-06  Office Supplies   685.340
# ...         ...              ...       ...
# 2854 2017-12-29  Office Supplies   282.440
# 2855 2017-12-29       Technology   302.376
# 2856 2017-12-30        Furniture   323.136
# 2857 2017-12-30  Office Supplies   299.724
# 2858 2017-12-30       Technology    90.930
#
# [2859 rows x 3 columns]

# %%
df_groupby = df.groupby(["order_month", "category"]).agg({
    "sales" : "sum",
})
df_groupby
# Out:
#                                   sales
# order_month category
# 14-01       Furniture         6242.5250
#             Office Supplies   4851.0800
#             Technology        3143.2900
# 14-02       Furniture         1839.6580
#             Office Supplies   1071.7240
# ...                                 ...
# 17-11       Office Supplies  31472.3370
#             Technology       39418.8030
# 17-12       Furniture        31407.4668
#             Office Supplies  30436.9420
#             Technology       21984.9100
#
# [144 rows x 1 columns]

# %%
df_groupby = df_groupby.reset_index()
df_groupby
# Out:
#     order_month         category       sales
# 0         14-01        Furniture   6242.5250
# 1         14-01  Office Supplies   4851.0800
# 2         14-01       Technology   3143.2900
# 3         14-02        Furniture   1839.6580
# 4         14-02  Office Supplies   1071.7240
# ..          ...              ...         ...
# 139       17-11  Office Supplies  31472.3370
# 140       17-11       Technology  39418.8030
# 141       17-12        Furniture  31407.4668
# 142       17-12  Office Supplies  30436.9420
# 143       17-12       Technology  21984.9100
#
# [144 rows x 3 columns]

# %%
df_groupby = df_groupby.rename(columns=
                              {
                                  "order_month" : "month",
                              })
df_groupby
# Out:
#      month         category       sales
# 0    14-01        Furniture   6242.5250
# 1    14-01  Office Supplies   4851.0800
# 2    14-01       Technology   3143.2900
# 3    14-02        Furniture   1839.6580
# 4    14-02  Office Supplies   1071.7240
# ..     ...              ...         ...
# 139  17-11  Office Supplies  31472.3370
# 140  17-11       Technology  39418.8030
# 141  17-12        Furniture  31407.4668
# 142  17-12  Office Supplies  30436.9420
# 143  17-12       Technology  21984.9100
#
# [144 rows x 3 columns]

# %%
df_groupby.pivot(index="month",columns="category", values="sales")
# Out:
# category   Furniture  Office Supplies  Technology
# month
# 14-01      6242.5250         4851.080    3143.290
# 14-02      1839.6580         1071.724    1608.510
# 14-03     14573.9560         8605.879    9872.694
# 14-04      7944.8370        11155.074    9195.434
# 14-05      6912.7870         7135.624    9599.876
# 14-06     13206.1256        12953.037    8435.965
# 14-07     10821.0510        15121.208    8004.134
# 14-08      7320.3465        11379.462    9209.660
# 14-09     23816.4808        27423.298   30537.572
# 14-10     12304.2470         7211.128   11938.018
# 14-11     21564.8727        26862.436   30201.408
# 14-12     30645.9665        18006.462   20893.192
# 15-01     11739.9416         1808.780    4625.354
# 15-02      3134.3740         5368.067    3448.970
# 15-03     12499.7830        15882.547   10343.922
# 15-04     10475.6985        12558.558   11160.952
# 15-05      9374.9505         9113.736   11643.000
# 15-06      7714.1790        10647.747    6435.366
# 15-07     13674.4200         4719.939   10370.966
# 15-08      9638.5922        11735.108   15524.632
# 15-09     26273.0230        19305.767   19017.128
# 15-10     12026.6235         8673.410   10704.890
# 15-11     30880.8325        21218.130   23873.601
# 15-12     23085.8192        16201.674   35632.028
# 16-01      7622.7430         5299.682    5620.066
# 16-02      3925.5510         6794.350   12258.914
# 16-03     12801.0920        17346.931   21567.852
# 16-04     13212.0900        10647.447   14890.502
# 16-05     15119.8350        13035.202   28832.691
# 16-06     13070.5720        10901.810   16372.152
# 16-07     13068.5190        12924.444   13269.000
# 16-08     12483.2323         8959.740    9672.402
# 16-09     27262.8809        23263.738   22883.406
# 16-10     11872.5770        16281.794   14033.424
# 16-11     31783.6288        20487.278   22641.074
# 16-12     36678.7150        37997.566   22322.762
# 17-01      5964.0320        21274.289   16733.053
# 17-02      6866.3374         7407.772    6027.024
# 17-03     10893.4448        14550.286   19428.662
# 17-04      9065.9581        15072.191   12383.387
# 17-05     16957.5582        13736.964   13566.588
# 17-06     19008.5867        16912.039   17061.100
# 17-07     11813.0220        10241.468   23209.926
# 17-08     15441.8740        30059.852   17619.162
# 17-09     29028.2060        31895.843   26942.603
# 17-10     21884.0682        23037.192   21655.695
# 17-11     37056.7150        31472.337   39418.803
# 17-12     31407.4668        30436.942   21984.910
